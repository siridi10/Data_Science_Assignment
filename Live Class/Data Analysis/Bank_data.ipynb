# %% [markdown]
# 1. How many campaign available in this dataset
# 2. How many people with loan and housing
# 3. How many people with 60+ age
# 4. In which month we have targeted most of customer
# 5. Which mode of call giving more result
# 6. How many entrepreneur in the list
# 7. How many customer with negative balance
# 8. Prepare a group of data based on education level

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/LaxmiChaudhary/Ensemble-Techniques-on-Bank-Data/master/bank-full.csv")

# %%
df
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       58     management   married   tertiary      no     2143     yes   no
# 1       44     technician    single  secondary      no       29     yes   no
# 2       33   entrepreneur   married  secondary      no        2     yes  yes
# 3       47    blue-collar   married    unknown      no     1506     yes   no
# 4       33        unknown    single    unknown      no        1      no   no
# 5       35     management   married   tertiary      no      231     yes   no
# 6       28     management    single   tertiary      no      447     yes  yes
# 7       42   entrepreneur  divorced   tertiary     yes        2     yes   no
# 8       58        retired   married    primary      no      121     yes   no
# 9       43     technician    single  secondary      no      593     yes   no
# 10      41         admin.  divorced  secondary      no      270     yes   no
# ...

# %%
# 1. How many campaign available in this dataset
df['campaign'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12, 13, 19, 14, 24, 16,
#        32, 18, 22, 15, 17, 25, 21, 43, 51, 63, 41, 26, 28, 55, 50, 38, 23,
#        20, 29, 31, 37, 30, 46, 27, 58, 33, 35, 34, 36, 39, 44],
#       dtype=int64)

# %%
df.groupby('campaign')['campaign'].count()
# Out:
# campaign
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 23       22
# 24       20
# 25       22
# 26       13
# 27       10
# 28       16
# 29       16
# 30        8
# 31       12
# 32        9
# 33        6
# 34        5
# 35        4
# 36        4
# 37        2
# 38        3
# 39        1
# 41        2
# 43        3
# 44        1
# 46        1
# 50        2
# 51        1
# 55        1
# 58        1
# 63        1
# Name: campaign, dtype: int64

# %%
# 2. How many people with loan and housing
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
df['housing']=='yes'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 45181    False
# 45182    False
# 45183    False
# 45184    False
# 45185     True
# 45186    False
# 45187     True
# 45188     True
# 45189    False
# 45190    False
# 45191     True
# 45192    False
# 45193    False
# 45194     True
# 45195    False
# 45196    False
# 45197     True
# 45198    False
# 45199     True
# 45200     True
# 45201    False
# 45202    False
# 45203    False
# 45204    False
# 45205    False
# 45206    False
# 45207    False
# ...

# %%
df_housing = df[df['housing'] == 'yes']
df_housing
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       58     management   married   tertiary      no     2143     yes   no
# 1       44     technician    single  secondary      no       29     yes   no
# 2       33   entrepreneur   married  secondary      no        2     yes  yes
# 3       47    blue-collar   married    unknown      no     1506     yes   no
# 5       35     management   married   tertiary      no      231     yes   no
# 6       28     management    single   tertiary      no      447     yes  yes
# 7       42   entrepreneur  divorced   tertiary     yes        2     yes   no
# 8       58        retired   married    primary      no      121     yes   no
# 9       43     technician    single  secondary      no      593     yes   no
# 10      41         admin.  divorced  secondary      no      270     yes   no
# 11      29         admin.    single  secondary      no      390     yes   no
# ...

# %%
df_housing[df_housing['loan'] == 'yes']
# Out:
#        age            job   marital  education default  balance housing loan  \
# 2       33   entrepreneur   married  secondary      no        2     yes  yes
# 6       28     management    single   tertiary      no      447     yes  yes
# 20      28    blue-collar   married  secondary      no      723     yes  yes
# 22      32    blue-collar    single    primary      no       23     yes  yes
# 24      40        retired   married    primary      no        0     yes  yes
# 27      52   entrepreneur   married  secondary      no      113     yes  yes
# 29      36     technician    single  secondary      no      265     yes  yes
# 32      60         admin.   married  secondary      no       39     yes  yes
# 54      24     technician    single  secondary      no     -103     yes  yes
# 69      35    blue-collar    single  secondary      no    12223     yes  yes
# 70      57    blue-collar   married  secondary      no     5935     yes  yes
# ...

# %%
len(df_housing[df_housing['loan'] == 'yes'])
# Out:
# 4367

# %%
# 3. How many people with 60+ age
df.head(5)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
df[df['age']>60]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 199     61    blue-collar  divorced    primary      no     1428     yes   no
# 575     61        retired   married  secondary      no      195     yes  yes
# 1233    61    blue-collar   married    primary      no      734     yes   no
# 2435    61        retired   married    primary      no     1060     yes   no
# 2992    61        retired   married  secondary      no     4248     yes   no
# 3615    61        retired   married  secondary      no      280     yes   no
# 4181    61    blue-collar   married    primary      no      625     yes   no
# 6722    61        retired  divorced  secondary      no     1857     yes   no
# 8128    61        retired   married    primary      no     -156     yes  yes
# 8625    61        retired   married    primary      no      296     yes  yes
# 9130    61      housemaid   married    unknown      no        0      no   no
# ...

# %%
len(df[df['age']>60])
# Out:
# 1188

# %%
# 4. In which month we have targeted most of customer
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
month = df.groupby('month')['month'].count()

# %%
month.sort_values(ascending=False)
# Out:
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64

# %%
# 5. Which mode of call giving more result
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
df.groupby('contact')['contact'].count()
# Out:
# contact
# cellular     29285
# telephone     2906
# unknown      13020
# Name: contact, dtype: int64

# %%
# 6. How many entrepreneur in the list
df[df['job'] == 'entrepreneur']
# Out:
#        age           job   marital  education default  balance housing loan  \
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 7       42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 27      52  entrepreneur   married  secondary      no      113     yes  yes
# 55      38  entrepreneur    single   tertiary      no      243      no  yes
# 94      57  entrepreneur  divorced  secondary      no      -37      no   no
# 172     53  entrepreneur   married    unknown      no       19     yes   no
# 222     35  entrepreneur  divorced  secondary      no      -69     yes   no
# 232     57  entrepreneur   married  secondary      no      294     yes   no
# 241     43  entrepreneur   married    unknown      no      100     yes   no
# 256     59  entrepreneur  divorced  secondary      no      901     yes   no
# 264     41  entrepreneur   married    primary      no      236     yes   no
# ...

# %%
len(df[df['job'] == 'entrepreneur'])
# Out:
# 1487

# %%
# 7. How many customer with negative balance
df[df['balance'] < 0]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 25      44         admin.   married  secondary      no     -372     yes   no
# 28      46     management    single  secondary      no     -246     yes   no
# 36      25    blue-collar   married  secondary      no       -7     yes   no
# 37      53     technician   married  secondary      no       -3      no   no
# 45      36         admin.    single    primary      no     -171     yes   no
# 46      58  self-employed   married   tertiary      no     -364     yes   no
# 51      48     management  divorced   tertiary      no     -244     yes   no
# 53      42         admin.    single  secondary      no      -76     yes   no
# 54      24     technician    single  secondary      no     -103     yes  yes
# 94      57   entrepreneur  divorced  secondary      no      -37      no   no
# 100     44    blue-collar   married  secondary      no     -674     yes   no
# ...

# %%
len(df[df['balance'] < 0])
# Out:
# 3766

# %%
# 8. Prepare a group of data based on education level
df.groupby('education')

# %%
ind=df.groupby('education').size().index
ind
# Out:
# Index(['primary', 'secondary', 'tertiary', 'unknown'], dtype='object', name='education')

# %%
ind[0]
# Out:
# 'primary'

# %%
df.groupby('education').get_group(ind[0])
# Out:
#        age            job   marital education default  balance housing loan  \
# 8       58        retired   married   primary      no      121     yes   no
# 15      51        retired   married   primary      no      229     yes   no
# 17      57    blue-collar   married   primary      no       52     yes   no
# 18      60        retired   married   primary      no       60     yes   no
# 22      32    blue-collar    single   primary      no       23     yes  yes
# 24      40        retired   married   primary      no        0     yes  yes
# 45      36         admin.    single   primary      no     -171     yes   no
# 59      46       services   married   primary      no      179     yes   no
# 62      57    blue-collar   married   primary      no      249     yes   no
# 73      55    blue-collar   married   primary      no       23     yes   no
# 85      51    blue-collar   married   primary      no      173     yes   no
# ...

# %%
df.groupby('education').get_group(ind[1])
# Out:
#        age           job   marital  education default  balance housing loan  \
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 9       43    technician    single  secondary      no      593     yes   no
# 10      41        admin.  divorced  secondary      no      270     yes   no
# 11      29        admin.    single  secondary      no      390     yes   no
# 12      53    technician   married  secondary      no        6     yes   no
# 14      57      services   married  secondary      no      162     yes   no
# 19      33      services   married  secondary      no        0     yes   no
# 20      28   blue-collar   married  secondary      no      723     yes  yes
# 23      25      services   married  secondary      no       50     yes   no
# 25      44        admin.   married  secondary      no     -372     yes   no
# ...

# %%
df.groupby('education').get_group(ind[2])
# Out:
#        age            job   marital education default  balance housing loan  \
# 0       58     management   married  tertiary      no     2143     yes   no
# 5       35     management   married  tertiary      no      231     yes   no
# 6       28     management    single  tertiary      no      447     yes  yes
# 7       42   entrepreneur  divorced  tertiary     yes        2     yes   no
# 21      56     management   married  tertiary      no      779     yes   no
# 26      39     management    single  tertiary      no      255     yes   no
# 31      49     management   married  tertiary      no      378     yes   no
# 34      51     management   married  tertiary      no    10635     yes   no
# 46      58  self-employed   married  tertiary      no     -364     yes   no
# 49      29     management    single  tertiary      no        0     yes   no
# 51      48     management  divorced  tertiary      no     -244     yes   no
# ...

# %%
df.groupby('education').get_group(ind[3])
# Out:
#        age           job   marital education default  balance housing loan  \
# 3       47   blue-collar   married   unknown      no     1506     yes   no
# 4       33       unknown    single   unknown      no        1      no   no
# 13      58    technician   married   unknown      no       71     yes   no
# 16      45        admin.    single   unknown      no       13     yes   no
# 42      60   blue-collar   married   unknown      no      104     yes   no
# 44      58       retired   married   unknown      no       96     yes   no
# 57      47   blue-collar   married   unknown      no      306     yes   no
# 58      40   blue-collar    single   unknown      no       24     yes   no
# 64      49   blue-collar   married   unknown      no      154     yes   no
# 93      60   blue-collar   married   unknown      no       54     yes   no
# 120     56    technician  divorced   unknown      no       56     yes   no
# ...
