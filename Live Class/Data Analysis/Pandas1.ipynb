# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 722B-8F82
#
#  Directory of C:\Users\ADMIN\Pandas
#
# 28-02-2022  13:07    <DIR>          .
# 28-02-2022  13:05    <DIR>          ..
# 28-02-2022  13:05    <DIR>          .ipynb_checkpoints
# 28-02-2022  13:07               555 Pandas.ipynb
#                1 File(s)            555 bytes
#                3 Dir(s)  133,121,241,088 bytes free

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 722B-8F82
#
#  Directory of C:\Users\ADMIN\Pandas
#
# 28-02-2022  13:15    <DIR>          .
# 28-02-2022  13:05    <DIR>          ..
# 28-02-2022  13:05    <DIR>          .ipynb_checkpoints
# 28-02-2022  13:15               214 Book1.csv
# 28-02-2022  13:15             1,423 Pandas.ipynb
#                2 File(s)          1,637 bytes
#                3 Dir(s)  133,120,372,736 bytes free

# %%
pd.read_csv('Book1.csv')
# Out:
#      name               emailid   address  pincode sirname
# 0  siridi  siridirock@gmail.com  rayagada   765001    siri
# 1     sai     sainath@gmail.com  rayagada   765002     sai
# 2    chen        chen@gmail.com   chennai   788999     kkk
# 3  pandas      pandas@gmail.com     panda   999999    klkp

# %% [markdown]
# # Trying to read csv file directly from directory

# %%
pd.read_csv('G:\INEURON_ASSIGNMENT\Pandas\services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
type(pd)
# Out:
# module

# %%
pd.read_csv('G:\INEURON_ASSIGNMENT\Pandas\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv('G:/INEURON_ASSIGNMENT/Pandas/taxonomy.csv')
# Out:
#       taxonomy_id                            name  parent_id  \
# 0             101                       Emergency        NaN
# 1          101-01               Disaster Response        101
# 2          101-02                  Emergency Cash        101
# 3       101-02-01               Help Pay for Food     101-02
# 4       101-02-02         Help Pay for Healthcare     101-02
# 5       101-02-03            Help Pay for Housing     101-02
# 6       101-02-04                Help Pay for Gas     101-02
# 7       101-02-05             Help Pay for School     101-02
# 8       101-02-06          Help Pay for Utilities     101-02
# 9          101-03                  Emergency Food        101
# 10         101-04               Emergency Shelter        101
# 11         101-05       Help Find Missing Persons        101
# 12         101-06                Immediate Safety        101
# 13      101-06-01            Help Escape Violence     101-06
# ...

# %%
pd.read_csv('G:/INEURON_ASSIGNMENT/Pandas/taxonomy.csv',header=None)
# Out:
#                 0                               1          2  \
# 0     taxonomy_id                            name  parent_id
# 1             101                       Emergency        NaN
# 2          101-01               Disaster Response        101
# 3          101-02                  Emergency Cash        101
# 4       101-02-01               Help Pay for Food     101-02
# 5       101-02-02         Help Pay for Healthcare     101-02
# 6       101-02-03            Help Pay for Housing     101-02
# 7       101-02-04                Help Pay for Gas     101-02
# 8       101-02-05             Help Pay for School     101-02
# 9       101-02-06          Help Pay for Utilities     101-02
# 10         101-03                  Emergency Food        101
# 11         101-04               Emergency Shelter        101
# 12         101-05       Help Find Missing Persons        101
# 13         101-06                Immediate Safety        101
# ...

# %%
pd.read_csv('G:/INEURON_ASSIGNMENT/Pandas/taxonomy.csv',names=['aa','bb','cc','dd'])
# Out:
#                aa                              bb         cc  \
# 0     taxonomy_id                            name  parent_id
# 1             101                       Emergency        NaN
# 2          101-01               Disaster Response        101
# 3          101-02                  Emergency Cash        101
# 4       101-02-01               Help Pay for Food     101-02
# 5       101-02-02         Help Pay for Healthcare     101-02
# 6       101-02-03            Help Pay for Housing     101-02
# 7       101-02-04                Help Pay for Gas     101-02
# 8       101-02-05             Help Pay for School     101-02
# 9       101-02-06          Help Pay for Utilities     101-02
# 10         101-03                  Emergency Food        101
# 11         101-04               Emergency Shelter        101
# 12         101-05       Help Find Missing Persons        101
# 13         101-06                Immediate Safety        101
# ...

# %%
pd.read_csv('G:/INEURON_ASSIGNMENT/Pandas/taxonomy.csv',names=['aa','bb','cc'])
# Out:
#                                           aa         bb  \
# taxonomy_id                             name  parent_id
# 101                                Emergency        NaN
# 101-01                     Disaster Response        101
# 101-02                        Emergency Cash        101
# 101-02-01                  Help Pay for Food     101-02
# 101-02-02            Help Pay for Healthcare     101-02
# 101-02-03               Help Pay for Housing     101-02
# 101-02-04                   Help Pay for Gas     101-02
# 101-02-05                Help Pay for School     101-02
# 101-02-06             Help Pay for Utilities     101-02
# 101-03                        Emergency Food        101
# 101-04                     Emergency Shelter        101
# 101-05             Help Find Missing Persons        101
# 101-06                      Immediate Safety        101
# 101-06-01               Help Escape Violence     101-06
# 101-06-02                       Safe Housing     101-06
# ...

# %%
pd.read_csv('Book1.csv')
# Out:
#                name@emailid@address@pincode@sirname
# 0  siridi@siridirock@gmail.com@rayagada@765001@siri
# 1         sai@sainath@gmail.com@rayagada@765002@sai
# 2            chen@chen@gmail.com@chennai@788999@kkk
# 3         pandas@pandas@gmail.com@panda@999999@klkp

# %%
pd.read_csv('Book1.csv',sep='|')
# Out:
#      name               emailid   address  pincode sirname
# 0  siridi  siridirock@gmail.com  rayagada   765001    siri
# 1     sai     sainath@gmail.com  rayagada   765002     sai
# 2    chen        chen@gmail.com   chennai   788999     kkk
# 3  pandas      pandas@gmail.com     panda   999999    klkp

# %%
df=pd.read_csv('G:/INEURON_ASSIGNMENT/Pandas/services.csv')

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
# try to show only first 5 records from top
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
# try to show only first 5 records from bottom
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#for showing one column
df['name']
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
#for showing multiple columns we need to insert another square brackets([])
df[['name','location_id']]
# Out:
#                                     name  location_id
# 0        Fair Oaks Adult Activity Center            1
# 1       Second Career Employment Program            2
# 2                 Senior Peer Counseling            3
# 3               Family Visitation Center            4
# 4      Economic Self-Sufficiency Program            5
# 5   Little House Recreational Activities            6
# 6       Rosener House Adult Day Services            7
# 7         Meals on Wheels - South County            8
# 8                       Fair Oaks Branch            9
# 9                           Main Library           10
# 10                       Schaberg Branch           11
# 11                          Project Read           12
# 12                 Redwood Shores Branch           13
# 13                    Redwood City Corps           14
# 14           Adult Rehabilitation Center           15
# 15                       Sunnyvale Corps           16
# ...

# %%
df[['name','location_id','fees']]
# Out:
#                                     name  location_id  \
# 0        Fair Oaks Adult Activity Center            1
# 1       Second Career Employment Program            2
# 2                 Senior Peer Counseling            3
# 3               Family Visitation Center            4
# 4      Economic Self-Sufficiency Program            5
# 5   Little House Recreational Activities            6
# 6       Rosener House Adult Day Services            7
# 7         Meals on Wheels - South County            8
# 8                       Fair Oaks Branch            9
# 9                           Main Library           10
# 10                       Schaberg Branch           11
# 11                          Project Read           12
# 12                 Redwood Shores Branch           13
# 13                    Redwood City Corps           14
# 14           Adult Rehabilitation Center           15
# 15                       Sunnyvale Corps           16
# ...

# %% [markdown]
# # fetching data directly from github url

# %%
# we need to click on raw and copy the url
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
